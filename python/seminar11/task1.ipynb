# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### Уравнение
# f(x) = -12x^4 - 18x^3+5x^2 + 10x

# %%
def f(x):
    return -12*x*x*x*x - 18*x*x*x + 5*x*x + 10*x

# %% [markdown]
# ### Задание 1.
# Определить корни

# %%
from sympy import diff, symbols, Eq, S, solve
from cmath import *

x = symbols('x', real=True)
#fx = -12*x*x*x*x - 18*x*x*x + 5*x*x + 10*x
#answer = solve(fx)
answer = solve(Eq(-12*x**4 - 18*x**3 + 5*x**2 + 10*x,0),x)
print('Корни исходного уравнения из solve:')
I=sqrt(-1)
ans=[]
for a in answer:
    print(str(a))
    ans.append(eval(str(a)).real)
print('Корни, приведенные к действительному виду (их мнимая часть стремится к 0):')
ans.sort()
for a in ans:
    print(a)
# Out:
# Корни исходного уравнения из solve:
# 0
# -1/2 + (-1/2 - sqrt(3)*I/2)*(3/16 + sqrt(4415)*I/432)**(1/3) + 7/(18*(-1/2 - sqrt(3)*I/2)*(3/16 + sqrt(4415)*I/432)**(1/3))
# -1/2 + 7/(18*(-1/2 + sqrt(3)*I/2)*(3/16 + sqrt(4415)*I/432)**(1/3)) + (-1/2 + sqrt(3)*I/2)*(3/16 + sqrt(4415)*I/432)**(1/3)
# -1/2 + 7/(18*(3/16 + sqrt(4415)*I/432)**(1/3)) + (3/16 + sqrt(4415)*I/432)**(1/3)
# Корни, приведенные к действительному виду (их мнимая часть стремится к 0):
# -1.352523311730382
# -0.8621352422032016
# 0
# 0.7146585539335835

# %% [markdown]
# ### Задания 2 и 3.
# Найти интервалы, на которых функция возрастает и убывает

# %%
import numpy as np
x = symbols('x')
d = diff(-12*x*x*x*x - 18*x*x*x + 5*x*x + 10*x) 
print("Дифференцированное исходное уравнение df(x):")
print(d)

danswer = solve(d,x)
I=sqrt(-1)
dans=[]
for a in danswer:
    dans.append(eval(str(a)).real)
print('Корни, дифференцированного уравнения df(x):')
dans.sort()
for a in dans:
    print(a)


def df(x):
    return -48*x**3 - 54*x**2 + 10*x + 10

x = np.linspace(-1.5, 1, 50)
#dy = [df(n) for n in x]
y = -12*x*x*x*x - 18*x*x*x + 5*x*x + 10*x
dy = -48*x**3 - 54*x**2 + 10*x + 10
y0 = [0 for n in x]

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.spines['left'].set_position('center')
ax.spines['bottom'].set_position('zero')
#plt.fill_between(x, y0, dy, where=(dy>y0), color='green')
plt.plot(x, y0, color='black')
plt.plot(x, dy, color='black')
plt.fill_between(x, y0, dy, where=(y0 < dy), color='green')
plt.fill_between(x, y0, dy, where=(y0 > dy), color='red')

print(f"\n----------- Поведение функции f(x) при аргументе х:\n\
    менее {dans[0]} - растет\n\
    от {dans[0]} до {dans[1]} - убывает\n\
    от {dans[1]} до {dans[2]} - растет\n\
    более {dans[2]} - убывает\n\n")
print("В зеленой зоне исходная функция растет, в красной убывает")
plt.show()
# Out:
# Дифференцированное исходное уравнение df(x):
# -48*x**3 - 54*x**2 + 10*x + 10
# Корни, дифференцированного уравнения df(x):
# -1.1484482835381318
# -0.4143529027337699
# 0.4378011862719018
#
# ----------- Поведение функции f(x) при аргументе х:
#     менее -1.1484482835381318 - растет
#     от -1.1484482835381318 до -0.4143529027337699 - убывает
#     от -0.4143529027337699 до 0.4378011862719018 - растет
#     более 0.4378011862719018 - убывает
#
#
# В зеленой зоне исходная функция растет, в красной убывает

# %% [markdown]
# ### Задание 4.
# Построить график

# %%
print("График исходной функции f(x):")

# Setting axis at the center
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
 
# Move left y-axis and bottim x-axis to centre, passing through (0,0)
ax.spines['left'].set_position('center')
ax.spines['bottom'].set_position('zero')
 
# Eliminate upper and right axes
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
 
# Show ticks in the left and lower axes only
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

plt.plot(x, y)
plt.show()
# Out:
# График исходной функции f(x):

# %% [markdown]
# ### Задание 5.
# Вычислить вершину

# %%
print("На графике исходной функции f(x) отмечены точки локальных экстремумов:")
ydans = [f(n) for n in dans]

plt.plot(x, y)
plt.scatter(dans, ydans)
plt.show()

#поиск максимального экстремума исходной функции
ii=0
for i in range(len(dans)):
    if ydans[i] > ydans[ii]:
        ii=i

print("Награфике f(x) указана вершина (максимальное значение функции):")
plt.plot(x, y)
plt.scatter(dans[ii], ydans[ii])
plt.show()

print(f"Максимальное значение функции f(x):\n\
    f({dans[ii]}) = {ydans[ii]}\n")
# Out:
# На графике исходной функции f(x) отмечены точки локальных экстремумов:
# Награфике f(x) указана вершина (максимальное значение функции):
# Максимальное значение функции f(x):
#     f(0.4378011862719018) = 3.385073742586306

# %% [markdown]
# ### Задания 6 и 7.
# Определить промежутки, на которых f(x) > 0 и f(x) < 0

# %%
print(f"Функция f(x) в диапазоне значений аргумента x:\n\
    x менее {ans[0]}: < 0\n\
    x от {ans[0]} до {ans[1]}: > 0\n\
    x от {ans[1]} до {ans[2]}: < 0\n\
    x от {ans[2]} до {ans[3]}: > 0\n\
    x более {ans[3]}: < 0\n")

yans = [0 for n in ans]

# Setting axis at the center
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
# Move left y-axis and bottim x-axis to centre, passing through (0,0)
ax.spines['left'].set_position('center')
ax.spines['bottom'].set_position('zero')
# Eliminate upper and right axes
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
# Show ticks in the left and lower axes only
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')
plt.plot(x, y, color="black")
plt.plot(x, y0, color='black')
plt.fill_between(x, y0, y, where=(y0 < y), color='yellow')
plt.fill_between(x, y0, y, where=(y0 > y), color='cyan')
plt.scatter(ans, yans)
plt.show()
# Out:
# Функция f(x) в диапазоне значений аргумента x:
#     x менее -1.352523311730382: < 0
#     x от -1.352523311730382 до -0.8621352422032016: > 0
#     x от -0.8621352422032016 до 0: < 0
#     x от 0 до 0.7146585539335835: > 0
#     x более 0.7146585539335835: < 0
